# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\hp\Downloads\WHO-COVID-19-global-data.csv")

# %%
data.head()
# Out:
#   Date_reported  Country_code      Country  WHO_region   New_cases  \
# 0    2020-02-24            AF  Afghanistan        EMRO           5
# 1    2020-02-25            AF  Afghanistan        EMRO           0
# 2    2020-02-26            AF  Afghanistan        EMRO           0
# 3    2020-02-27            AF  Afghanistan        EMRO           0
# 4    2020-02-28            AF  Afghanistan        EMRO           0
#
#     Cumulative_cases   New_deaths   Cumulative_deaths
# 0                  5            0                   0
# 1                  5            0                   0
# 2                  5            0                   0
# 3                  5            0                   0
# 4                  5            0                   0

# %%
data.columns
# Out:
# Index(['Date_reported', ' Country_code', ' Country', ' WHO_region',
#        ' New_cases', ' Cumulative_cases', ' New_deaths', ' Cumulative_deaths'],
#       dtype='object')

# %%
data.tail()
# Out:
#       Date_reported  Country_code   Country  WHO_region   New_cases  \
# 35431    2020-08-12            ZW  Zimbabwe        AFRO          70
# 35432    2020-08-13            ZW  Zimbabwe        AFRO          75
# 35433    2020-08-14            ZW  Zimbabwe        AFRO          97
# 35434    2020-08-15            ZW  Zimbabwe        AFRO          82
# 35435    2020-08-16            ZW  Zimbabwe        AFRO         104
#
#         Cumulative_cases   New_deaths   Cumulative_deaths
# 35431               4818            0                 104
# 35432               4893           18                 122
# 35433               4990            6                 128
# 35434               5072            0                 128
# 35435               5176            2                 130

# %%
data.describe()
# Out:
#           New_cases   Cumulative_cases    New_deaths   Cumulative_deaths
# count  35436.000000       3.543600e+04  35436.000000        35436.000000
# mean     607.200587       3.364832e+04     21.635145         1610.365024
# std     3720.974493       2.063900e+05    132.639790         8839.933427
# min    -2461.000000       1.000000e+00  -5359.000000            0.000000
# 25%        0.000000       6.100000e+01      0.000000            1.000000
# 50%        8.000000       7.410000e+02      0.000000           13.000000
# 75%      129.000000       7.272250e+03      2.000000          147.000000
# max    74354.000000       5.312940e+06   6409.000000       168345.000000

# %%
data.isnull().sum()
# Out:
# Date_reported           0
#  Country_code         156
#  Country                0
#  WHO_region             0
#  New_cases              0
#  Cumulative_cases       0
#  New_deaths             0
#  Cumulative_deaths      0
# dtype: int64

# %% [markdown]
# # relating the variables with scatterplots

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['Date_reported', ' Country_code', ' Country', ' WHO_region',
#        ' New_cases', ' Cumulative_cases', ' New_deaths', ' Cumulative_deaths'],
#       dtype='object')
