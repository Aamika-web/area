# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\hp\Downloads\datasets_3972_6215_data.csv")

# %%
data.head()
# Out:
#                id  gender         dob  zipcode employment_status  education  \
# 0    Amelia Nixon  female  1944-03-09    89136           retired  bachelors
# 1     Clara Hicks  female  1966-07-02    94105          employed     phd/md
# 2     Mason Brown    male  1981-05-31    89127          employed    masters
# 3    Michael Rice    male  1945-02-13    44101           retired  bachelors
# 4  Eleanor Ritter  female  1939-09-03    89136           retired    masters
#
#   marital_status  children  ancestry  avg_commute  daily_internet_use  \
# 0        married         1  Portugal        13.38                2.53
# 1        married         4    Sweden        15.16                6.77
# 2        married         2   Germany        23.60                3.63
# 3        married         2   Denmark        19.61                5.00
# 4        married         3   Austria        36.55                7.75
#
#    available_vehicles military_service             disease
# ...

# %%
data.columns
# Out:
# Index(['id', 'gender', 'dob', 'zipcode', 'employment_status', 'education',
#        'marital_status', 'children', 'ancestry', 'avg_commute',
#        'daily_internet_use', 'available_vehicles', 'military_service',
#        'disease'],
#       dtype='object')

# %%
data.tail()
# Out:
#                      id  gender         dob  zipcode employment_status  \
# 1995      Ethan Johnson    male  1942-04-13    89127           retired
# 1996  Natalia Dominguez  female  1963-05-10    60612        unemployed
# 1997      Joseph Zuniga    male  1965-07-12    94110          employed
# 1998      Daniel Murphy    male  1926-08-10    90015           retired
# 1999      Samuel Harris    male  1948-11-22    43210           retired
#
#        education marital_status  children     ancestry  avg_commute  \
# 1995     masters        married         1  Switzerland        28.48
# 1996  highschool        married         4      Denmark        21.09
# 1997   bachelors        married         2       Russia        30.80
# 1998   bachelors        married         3      Finland        37.56
# 1999   bachelors        married         5     Scotland        49.34
#
#       daily_internet_use  available_vehicles military_service          disease
# ...

# %%
data.describe()
# Out:
#             zipcode     children  avg_commute  daily_internet_use  \
# count   2000.000000  2000.000000  2000.000000         2000.000000
# mean   63387.827500     2.266500    30.376895            4.993325
# std    30165.490876     1.615792    10.026961            1.387846
# min    10001.000000     0.000000    -2.470000            1.010000
# 25%    43221.000000     1.000000    23.460000            4.020000
# 50%    60612.000000     2.000000    30.320000            5.010000
# 75%    90008.000000     3.000000    37.127500            5.972500
# max    94110.000000     7.000000    63.730000            8.820000
#
#        available_vehicles
# count         2000.000000
# mean             1.746000
# std              1.118977
# min              0.000000
# 25%              1.000000
# 50%              2.000000
# 75%              3.000000
# max              4.000000

# %%
data.isnull().sum()
# Out:
# id                    0
# gender                0
# dob                   0
# zipcode               0
# employment_status     0
# education             0
# marital_status        0
# children              0
# ancestry              0
# avg_commute           0
# daily_internet_use    0
# available_vehicles    0
# military_service      0
# disease               0
# dtype: int64

# %%
data.groupby('avg_commute')['daily_internet_use']

# %%
sns.catplot(x="avg_commute",y="daily_internet_use",data=data,jitter="0.25")

# %%
sns.catplot(x="avg_commute",y="daily_internet_use",data=data,jitter=false,height=4, aspect=1.5)

# %%
sns.catplot(x="Disease", kind="count", data=data);

# %%
sns.pairplot(data)
