# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_df = pd.read_csv(r"C:\Users\hp\Downloads\datasets_831814_1420875_sea_levels_2015.csv")

# %%
data_df.head()
# Out:
#          Time   GMSL  GMSL uncertainty
# 0  1880-01-15 -183.0              24.2
# 1  1880-02-15 -171.1              24.2
# 2  1880-03-15 -164.3              24.2
# 3  1880-04-15 -158.2              24.2
# 4  1880-05-15 -158.7              24.2

# %%
fig = plt.figure(figsize=(10,6))

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.06,0.65,0.5,0.3])
ax1.set_title("sea level graph")

ax1.plot(data_df['Time'],data_df['GMSL'],color = 'green')

plt.show()

# %%
fig = plt.figure(figsize=(15,7))

fig.suptitle("sea level chnage between 2050",fontsize=20)
ax1 = fig.add_subplot(231)
ax1.set_title('GMSL')
ax1.plot(data_df['Time'],data_df['GMSL'],color = 'green')


plt.show()
